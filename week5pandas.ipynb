# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd

df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# Indexing into a dataframe creates a Pandas Series

# %%
df['age']
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
df[['age', 'sex', 'cp']]
# Out:
#      age  sex  cp
# 0     63    1   3
# 1     37    1   2
# 2     41    0   1
# 3     56    1   1
# 4     57    0   0
# ..   ...  ...  ..
# 298   57    0   0
# 299   45    1   3
# 300   68    1   0
# 301   57    1   0
# 302   57    0   1
#
# [303 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %%
df['age'].mean()
# Out:
# 54.366336633663366

# %%
df.shape
# Out:
# (303, 14)

# %%
len(df)
# Out:
# 303

# %% [markdown]
# Indexing into specific row(s) and column(s) of the dataframe:
#
# `.loc` is labeled based

# %%
df.loc[[0, 1, 2, 3, 4], ['age', 'sex', 'cp']]
# Out:
#    age  sex  cp
# 0   63    1   3
# 1   37    1   2
# 2   41    0   1
# 3   56    1   1
# 4   57    0   0

# %% [markdown]
# `iloc` is integer location based

# %%
df.iloc[0]
# Out:
# age          63.0
# sex           1.0
# cp            3.0
# trestbps    145.0
# chol        233.0
# fbs           1.0
# restecg       0.0
# thalach     150.0
# exang         0.0
# oldpeak       2.3
# slope         0.0
# ca            0.0
# thal          1.0
# target        1.0
# Name: 0, dtype: float64

# %% [markdown]
# You can also slice into the index rows using `iloc`

# %%
df.iloc[0:10]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %% [markdown]
# Transforming Data:

# %%
df['Transformed chol'] = df['chol'] * 100
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target  Transformed chol
# 0   0     1       1             23300
# 1   0     2       1             25000
# 2   0     2       1             20400
# 3   0     2       1             23600
# 4   0     2       1             35400

# %%
df['exang'] = df['exang'].astype(bool)
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150  False      2.3      0
# 1   37    1   2       130   250    0        1      187  False      3.5      0
# 2   41    0   1       130   204    0        0      172  False      1.4      2
# 3   56    1   1       120   236    0        1      178  False      0.8      2
# 4   57    0   0       120   354    0        1      163   True      0.6      2
#
#    ca  thal  target  Transformed chol
# 0   0     1       1             23300
# 1   0     2       1             25000
# 2   0     2       1             20400
# 3   0     2       1             23600
# 4   0     2       1             35400

# %% [markdown]
# Selecting rows based on criteria:

# %%
# selects observations where age >= 50

df['age'] >= 50
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 298     True
# 299    False
# 300     True
# 301     True
# 302     True
# Name: age, Length: 303, dtype: bool

# %%
df[df['age'] >= 50]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150  False      2.3
# 3     56    1   1       120   236    0        1      178  False      0.8
# 4     57    0   0       120   354    0        1      163   True      0.6
# 5     57    1   0       140   192    0        1      148  False      0.4
# 6     56    0   1       140   294    0        0      153  False      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90  False      1.0
# 298   57    0   0       140   241    0        1      123   True      0.2
# 300   68    1   0       144   193    1        1      141  False      3.4
# 301   57    1   0       130   131    0        1      115   True      1.2
# 302   57    0   1       130   236    0        0      174  False      0.0
#
#      slope  ca  thal  target  Transformed chol
# ...

# %%
(df['age'] >= 50) & (df['sex'] == 1)
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 298    False
# 299    False
# 300     True
# 301     True
# 302    False
# Length: 303, dtype: bool

# %%
df[(df['age'] >= 50) & (df['sex'] == 1)]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150  False      2.3
# 3     56    1   1       120   236    0        1      178  False      0.8
# 5     57    1   0       140   192    0        1      148  False      0.4
# 8     52    1   2       172   199    1        1      162  False      0.5
# 9     57    1   2       150   168    0        1      174  False      1.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 293   67    1   2       152   212    0        0      150  False      0.8
# 295   63    1   0       140   187    0        0      144   True      4.0
# 297   59    1   0       164   176    1        0       90  False      1.0
# 300   68    1   0       144   193    1        1      141  False      3.4
# 301   57    1   0       130   131    0        1      115   True      1.2
#
#      slope  ca  thal  target  Transformed chol
# ...

# %% [markdown]
# Applying a function to a column of data using apply:

# %%
def add_one(x):
    return x + 1

# %%
df['oldpeak'].apply(add_one)
# Out:
# 0      3.3
# 1      4.5
# 2      2.4
# 3      1.8
# 4      1.6
#       ...
# 298    1.2
# 299    2.2
# 300    4.4
# 301    2.2
# 302    1.0
# Name: oldpeak, Length: 303, dtype: float64

# %%
## This does not save it to your dataframe!

df['oldpeak add one'] = df['oldpeak'].apply(add_one)
